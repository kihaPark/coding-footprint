# %% [markdown]
# ## 울산광역시, 127586
# ## 데이터 전처리
# 1. 필요없는 컬럼 빼기
# 2. region_sub 컬럼 원핫인코딩 형식 수정
# 3. 컬럼별 상관관계 파악 컬럼 제거
# 4. price_cat 컬럼 추가

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

region_name = 'us_region'

# %%
readD = pd.read_csv(f'region-data-files/{region_name}.csv')
readD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127586 entries, 0 to 127585
# Columns: 105 entries, region to all_loan
# dtypes: float64(72), int64(26), object(7)
# memory usage: 102.2+ MB

# %%
all_col = {
    'region', 'region_sub', 'apt_name', 'apt_size', 'apt_floor', 'contract_date', 'contract_price',
    'completion_year', 'period_completed', 'pyung', 'price_per_pyung', 'contract_year', 'value_year',
    'value_factor', 'price_per_pyung_present', 'contract_date_key', 'index',  'date_ym', 'kospi',
    'kospi200', 'kospi200construct', 'kosdaq', 'dowjones', 's&p500', 'shanghai', 'nikkei',
    'exchange_rate', 'gold', 'oil', 'export', 'import', 'cpi_living', 'cpi', 'ccsi',
    'loan_interest_rate', 'housing_loan_rate',
    
    'gw_ratio', 'gg_ratio', 'gsn_ratio', 'gsb_ratio', 'gj_ratio', 'dg_ratio', 'dj_ratio',
    'bs_ratio', 'so_ratio', 'sj_ratio', 'us_ratio', 'ic_ratio', 'jrn_ratio', 'jrb_ratio',
    'jj_ratio', 'ccn_ratio', 'ccb_ratio', 'all_ratio',
    
    'gw_pop', 'gg_pop', 'gsn_pop', 'gsb_pop', 'gj_pop', 'dg_pop', 'dj_pop', 'bs_pop',
    'so_pop', 'sj_pop', 'us_pop', 'ic_pop', 'jrn_pop', 'jrb_pop', 'jj_pop', 'ccn_pop', 'ccb_pop',
    
    'all_re_ccsi', 'so_re_ccsi', 'ic_re_ccsi', 'gg_re_ccsi', 'bs_re_ccsi', 'dg_re_ccsi',
    'gj_re_ccsi', 'dj_re_ccsi', 'us_re_ccsi', 'gw_re_ccsi', 'ccb_re_ccsi', 'ccn_re_ccsi',
    'jrb_re_ccsi', 'jrn_re_ccsi', 'gsb_re_ccsi', 'gsn_re_ccsi',
    
    'gw_loan', 'gg_loan', 'gsn_loan', 'gsb_loan', 'gj_loan', 'dg_loan', 'dj_loan',
    'bs_loan', 'so_loan', 'sj_loan', 'us_loan', 'ic_loan', 'jrn_loan', 'jrb_loan',
    'jj_loan', 'ccn_loan', 'ccb_loan', 'all_loan'
}

# %%
drop_col_1 = {
    'region', 'apt_name', 'apt_size', 'contract_date', 'contract_price',
    'completion_year', 'price_per_pyung', 'contract_year', 'value_year',
    'value_factor', 'contract_date_key', 'index', 'date_ym', 'kospi',
    's&p500', 'nikkei', 'cpi', 'ccsi', 'housing_loan_rate',
    
    'gw_ratio', 'gg_ratio', 'gsn_ratio', 'gsb_ratio', 'gj_ratio', 'dg_ratio', 'dj_ratio',
    'bs_ratio', 'so_ratio', 'sj_ratio', 'us_ratio', 'ic_ratio', 'jrn_ratio', 'jrb_ratio',
    'jj_ratio', 'ccn_ratio', 'ccb_ratio', 'all_ratio',

    'gw_pop', 'gg_pop', 'gj_pop', 'dj_pop',
    'so_pop', 'sj_pop', 'ic_pop', 'jrn_pop', 'jrb_pop', 'jj_pop', 'ccn_pop', 'ccb_pop',

    'all_re_ccsi', 'so_re_ccsi', 'ic_re_ccsi', 'gg_re_ccsi', 'bs_re_ccsi', 'dg_re_ccsi',
    'gj_re_ccsi', 'dj_re_ccsi', 'gw_re_ccsi', 'ccb_re_ccsi', 'ccn_re_ccsi',
    'jrb_re_ccsi', 'jrn_re_ccsi', 'gsb_re_ccsi', 'gsn_re_ccsi',

    'gw_loan', 'gg_loan', 'gsn_loan', 'gsb_loan', 'gj_loan', 'dg_loan', 'dj_loan',
    'bs_loan', 'so_loan', 'sj_loan', 'ic_loan', 'jrn_loan', 'jrb_loan',
    'jj_loan', 'ccn_loan', 'ccb_loan', 'all_loan'
}

# %%
preD = readD.drop(columns=drop_col_1)
preD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127586 entries, 0 to 127585
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   region_sub               127586 non-null  object
#  1   apt_floor                127586 non-null  int64
#  2   period_completed         127586 non-null  int64
#  3   pyung                    127586 non-null  float64
#  4   price_per_pyung_present  127586 non-null  float64
#  5   kospi200                 127586 non-null  float64
#  6   kospi200construct        127586 non-null  float64
#  7   kosdaq                   127586 non-null  float64
#  8   dowjones                 127586 non-null  float64
#  9   shanghai                 127586 non-null  float64
#  10  exchange_rate            127586 non-null  float64
#  11  gold                     127586 non-null  float64
#  12  oil                      127586 non-null  float64
#  13  export                   127586 non-null  int64
#  14  import                   127586 non-null  int64
#  15  cpi_living               127586 non-null  float64
#  16  loan_interest_rate       127586 non-null  float64
#  17  gsn_pop                  127586 non-null  int64
#  18  gsb_pop                  127586 non-null  int64
#  19  dg_pop                   127586 non-null  int64
#  20  bs_pop                   127586 non-null  int64
#  21  us_pop                   127586 non-null  int64
#  22  us_re_ccsi               127586 non-null  float64
#  23  us_loan                  127586 non-null  float64
# dtypes: float64(14), int64(9), object(1)
# memory usage: 23.4+ MB

# %%
# test = preD['region_sub'].str.split(expand=True)[0]
# test.value_counts()

preD['region_sub'] = preD['region_sub'].str.split(expand=True)[0]
preD['region_sub'].value_counts()
# Out:
# 남구     41551
# 북구     24706
# 울주군    24478
# 중구     20104
# 동구     16747
# Name: region_sub, dtype: int64

# %%
drop_col_2 = {
    'gsb_pop'
}

preD.drop(columns=drop_col_2, inplace=True)
preD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127586 entries, 0 to 127585
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   region_sub               127586 non-null  object
#  1   apt_floor                127586 non-null  int64
#  2   period_completed         127586 non-null  int64
#  3   pyung                    127586 non-null  float64
#  4   price_per_pyung_present  127586 non-null  float64
#  5   kospi200                 127586 non-null  float64
#  6   kospi200construct        127586 non-null  float64
#  7   kosdaq                   127586 non-null  float64
#  8   dowjones                 127586 non-null  float64
#  9   shanghai                 127586 non-null  float64
#  10  exchange_rate            127586 non-null  float64
#  11  gold                     127586 non-null  float64
#  12  oil                      127586 non-null  float64
#  13  export                   127586 non-null  int64
#  14  import                   127586 non-null  int64
#  15  cpi_living               127586 non-null  float64
#  16  loan_interest_rate       127586 non-null  float64
#  17  gsn_pop                  127586 non-null  int64
#  18  dg_pop                   127586 non-null  int64
#  19  bs_pop                   127586 non-null  int64
#  20  us_pop                   127586 non-null  int64
#  21  us_re_ccsi               127586 non-null  float64
#  22  us_loan                  127586 non-null  float64
# dtypes: float64(14), int64(8), object(1)
# memory usage: 22.4+ MB

# %%
corr_matrix = preD.corr()
corr_matrix["price_per_pyung_present"].sort_values(ascending=False)
# Out:
# price_per_pyung_present    1.000000
# apt_floor                  0.260252
# pyung                      0.255407
# us_loan                    0.176049
# exchange_rate              0.171560
# dowjones                   0.148188
# cpi_living                 0.140852
# gsn_pop                    0.138249
# kosdaq                     0.123046
# shanghai                   0.110856
# kospi200                   0.049349
# gold                       0.048475
# us_pop                     0.003255
# us_re_ccsi                -0.052603
# export                    -0.122314
# import                    -0.133422
# bs_pop                    -0.159821
# dg_pop                    -0.174028
# oil                       -0.183303
# kospi200construct         -0.184446
# loan_interest_rate        -0.185779
# period_completed          -0.513621
# Name: price_per_pyung_present, dtype: float64

# %%
import seaborn as sns

plt.figure(figsize=(30,30))
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
print(preD['price_per_pyung_present'].describe())

preD['price_per_pyung_present'].hist()
plt.show()
# Out:
# count    1.275860e+05
# mean     9.909308e+06
# std      3.337206e+06
# min      1.253383e+06
# 25%      7.478794e+06
# 50%      9.659051e+06
# 75%      1.193073e+07
# max      3.477160e+07
# Name: price_per_pyung_present, dtype: float64

# %%
preD['price_cat'] = preD['price_per_pyung_present'] / 1.253383e+06  # min
print(preD['price_cat'].describe())
# Out:
# count    127586.000000
# mean          7.906050
# std           2.662559
# min           1.000000
# 25%           5.966887
# 50%           7.706384
# 75%           9.518819
# max          27.742201
# Name: price_cat, dtype: float64

# %%
def calc_price_categorize(D):

    if D['price_cat'] < 5.966887 : # 25%
        D['price_cat'] = 1.0
    elif D['price_cat'] < 7.706384 : # 50%
        D['price_cat'] = 2.0
    elif D['price_cat'] < 9.518819 : # 75%
        D['price_cat'] = 3.0
    else:
        D['price_cat'] = 4.0

    return D
    
preD = preD.apply(calc_price_categorize, axis=1)
preD['price_cat'].value_counts()
# Out:
# 4.0    31898
# 1.0    31897
# 2.0    31896
# 3.0    31895
# Name: price_cat, dtype: int64

# %%
# preD.to_csv(f'region-ml-data-files/{region_name}.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# ## 기계 학습
# 1. price_cat 분포별 데이터 나누기
# 2. train_set, test_set 나누기
# 3. 스케일 조정
# 4. 모델별 학습, 테스트
# 5. 모델 최적화

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

region_name = 'us_region'

# %%
readD = pd.read_csv(f'region-ml-data-files/{region_name}.csv')
readD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127586 entries, 0 to 127585
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   region_sub               127586 non-null  object
#  1   apt_floor                127586 non-null  int64
#  2   period_completed         127586 non-null  int64
#  3   pyung                    127586 non-null  float64
#  4   price_per_pyung_present  127586 non-null  float64
#  5   kospi200                 127586 non-null  float64
#  6   kospi200construct        127586 non-null  float64
#  7   kosdaq                   127586 non-null  float64
#  8   dowjones                 127586 non-null  float64
#  9   shanghai                 127586 non-null  float64
#  10  exchange_rate            127586 non-null  float64
#  11  gold                     127586 non-null  float64
#  12  oil                      127586 non-null  float64
#  13  export                   127586 non-null  int64
#  14  import                   127586 non-null  int64
#  15  cpi_living               127586 non-null  float64
#  16  loan_interest_rate       127586 non-null  float64
#  17  gsn_pop                  127586 non-null  int64
#  18  dg_pop                   127586 non-null  int64
#  19  bs_pop                   127586 non-null  int64
#  20  us_pop                   127586 non-null  int64
#  21  us_re_ccsi               127586 non-null  float64
#  22  us_loan                  127586 non-null  float64
#  23  price_cat                127586 non-null  float64
# dtypes: float64(15), int64(8), object(1)
# memory usage: 23.4+ MB

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.3, random_state=42)
for train_idx, test_idx in split.split(readD, readD["price_cat"]): # readD['price_cat'] 분포 유지
    train_set = readD.loc[train_idx]
    test_set = readD.loc[test_idx]

# %%
train_set['price_cat'].value_counts() / len(train_set)
# Out:
# 4.0    0.250017
# 1.0    0.250006
# 2.0    0.249994
# 3.0    0.249983
# Name: price_cat, dtype: float64

# %%
for set_ in (train_set, test_set):
    set_.drop('price_cat', axis=1, inplace=True)

# %%
train_set['price_per_pyung_present'].hist()
test_set['price_per_pyung_present'].hist()
plt.show()

# %%
x_train = train_set.drop('price_per_pyung_present', axis=1)
y_train = train_set['price_per_pyung_present'].copy()
x_test =  test_set.drop('price_per_pyung_present', axis=1)
y_test = test_set['price_per_pyung_present'].copy()

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class DataFrameSelector(BaseEstimator, TransformerMixin):
    
    def __init__(self, attribute_names):
        self.attribute_names = attribute_names
    
    def fit(self, x, y=None):
        return self
    
    def transform(self, x):
        return x[self.attribute_names].values

# %%
from sklearn.pipeline import Pipeline
from sklearn.pipeline import FeatureUnion
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import GradientBoostingRegressor

num_pipe = Pipeline([
        ('selector', DataFrameSelector(list(x_train)[1:])),
        ('std_scaler', StandardScaler())
    ])

cat_pipe = Pipeline([
        ('selector', DataFrameSelector(['region_sub'])),
        ('cat_encoder', OneHotEncoder(sparse=False))
    ])

prepro_pipe = FeatureUnion([
        ("num_pipe", num_pipe),
        ("cat_pipe", cat_pipe)
    ])

full_pipe = Pipeline([
        ('prepro', prepro_pipe),
        ("gbr", GradientBoostingRegressor())
    ])

x_train_nor = prepro_pipe.fit_transform(x_train)
# x_test_nor = prepro_pipe.fit_transform(x_test)

# %%
x_train_nor[1, :]
# Out:
# array([-1.27827707,  0.91294933, -1.50189851, -1.3625653 , -0.41474513,
#         0.58987443, -0.6901527 ,  0.41619299,  1.18429127, -1.26970256,
#        -0.94426844, -0.48937637, -1.40915777, -0.57634333, -0.87387529,
#         0.50066952,  0.33334454,  0.48448089,  1.3402114 ,  0.951827  ,
#        -0.06958785,  0.        ,  0.        ,  0.        ,  1.        ,
#         0.        ])

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {'gbr__n_estimators': [700, 800],
              'gbr__max_depth': [6, 7]}

grid = GridSearchCV(full_pipe, param_grid=param_grid, cv=3)
grid.fit(x_train, y_train)

print("최상의 교차 검증 정확도: ", grid.best_score_)
print("테스트 세트 점수: ", grid.score(x_test, y_test))
print("최적의 매개변수: {}".format(grid.best_params_))
# Out:
# 최상의 교차 검증 정확도:  0.8711374263297995
# 테스트 세트 점수:  0.8817868686268802
# 최적의 매개변수: {'gbr__max_depth': 7, 'gbr__n_estimators': 800}

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

test_pred = grid.predict(x_test)
grid_mse = mean_squared_error(y_test, test_pred)
grid_rmse = np.sqrt(grid_mse)
print('grid rmse: ', grid_rmse)

grid_mae = mean_absolute_error(y_test, test_pred)
print('grid mae: ', grid_mae)
# Out:
# grid rmse:  1147473.1241446347
# grid mae:  783292.3297625654

# %%
grid.cv_results_
# Out:
# {'mean_fit_time': array([146.40351184, 165.29845905, 171.81005581, 187.81858357]),
#  'std_fit_time': array([1.52735761, 0.68621763, 7.45158241, 2.84128705]),
#  'mean_score_time': array([0.46210893, 0.52128307, 0.57147169, 0.63630915]),
#  'std_score_time': array([0.00740075, 0.00170609, 0.01103781, 0.00651399]),
#  'param_gbr__max_depth': masked_array(data=[6, 6, 7, 7],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_gbr__n_estimators': masked_array(data=[700, 800, 700, 800],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'gbr__max_depth': 6, 'gbr__n_estimators': 700},
#   {'gbr__max_depth': 6, 'gbr__n_estimators': 800},
#   {'gbr__max_depth': 7, 'gbr__n_estimators': 700},
#   {'gbr__max_depth': 7, 'gbr__n_estimators': 800}],
#  'split0_test_score': array([0.85633016, 0.85947875, 0.86970175, 0.87293105]),
#  'split1_test_score': array([0.85649633, 0.8592427 , 0.8666878 , 0.86882653]),
#  'split2_test_score': array([0.85802356, 0.86142874, 0.8700401 , 0.87165471]),
#  'mean_test_score': array([0.85695002, 0.86005006, 0.86880988, 0.87113743]),
#  'std_test_score': array([0.00076214, 0.00097962, 0.00150688, 0.00171512]),
#  'rank_test_score': array([4, 3, 2, 1])}

# %%
final_model = grid.best_estimator_
final_model
# Out:
# Pipeline(steps=[('prepro',
#                  FeatureUnion(transformer_list=[('num_pipe',
#                                                  Pipeline(steps=[('selector',
#                                                                   DataFrameSelector(attribute_names=['apt_floor',
#                                                                                                      'period_completed',
#                                                                                                      'pyung',
#                                                                                                      'kospi200',
#                                                                                                      'kospi200construct',
#                                                                                                      'kosdaq',
#                                                                                                      'dowjones',
#                                                                                                      'shanghai',
#                                                                                                      'exchange_rate',
#                                                                                                      'gold',
#                                                                                                      'oil',
#                                                                                                      'export',
#                                                                                                      'import',
#                                                                                                      'cpi_living',
#                                                                                                      'loan_interest_rate',
#                                                                                                      'gsn_pop',
#                                                                                                      'dg_pop',
#                                                                                                      'bs_pop',
#                                                                                                      'us_pop',
#                                                                                                      'us_re_ccsi',
#                                                                                                      'us_loan'])),
#                                                                  ('std_scaler',
#                                                                   StandardScaler())])),
#                                                 ('cat_pipe',
#                                                  Pipeline(steps=[('selector',
#                                                                   DataFrameSelector(attribute_names=['region_sub'])),
#                                                                  ('cat_encoder',
#                                                                   OneHotEncoder(sparse=False))]))])),
#                 ('gbr',
#                  GradientBoostingRegressor(max_depth=7, n_estimators=800))])

# %%
import joblib

joblib.dump(final_model, f'models/{region_name}.pkl')
# Out:
# ['models/us_region.pkl']

# %%
# test model
import joblib

gw_model = joblib.load(f'models/{region_name}.pkl')

test_pred = gw_model.predict(x_test)
grid_mse = mean_squared_error(y_test, test_pred)
grid_rmse = np.sqrt(grid_mse)
print('grid rmse: ', grid_rmse)
# Out:
# grid rmse:  1147473.1241446347
